# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
os.listdir()
# Out:
# ['.idea',
#  '.ipynb_checkpoints',
#  'Alissa Analysis.ipynb',
#  'Analysis_CSV_Files',
#  'Backup',
#  'bar-to-cash-ratios.csv',
#  'cash-to_bar-ratios.csv',
#  'data',
#  'desktop.ini',
#  'Employee.ipynb',
#  'Employee.py',
#  'Figures for Optimal Switching.ipynb',
#  'Mobile Orders Bypassing Physical.ipynb',
#  'Model Validation.ipynb',
#  'Original Operating Results',
#  'Original Operating Results.csv',
#  'Percent Improvements Collegetown Starbucks',
#  'Percent Improvements Collegetown Starbucks.csv',
#  'Person.py',
#  'pmobile 0.1 results',
#  'pmobile 0.1 results.csv',
#  'pmobile 0.3 results.csv',
#  'pmobile 0.9 result.csv',
#  'pmobile 0.9 results',
#  'pmobile 0.9 results.csv',
#  'pmobile r',
#  'Queue Length as pMobile changes with vac and aband.png',
#  'Queue Length as pMobile changes.png',
#  'QueueingFunction.py',
#  'Simulation Validation and Analysis.ipynb',
#  'SimulationAnalyser.py',
#  'Starbucks.py',
#  'Switching Operating Results',
# ...

# %%
b2c = pd.read_csv('bar-to-cash-ratios.csv',index_col=0)
c2b = pd.read_csv('cash-to_bar-ratios.csv',index_col=0)

# %%
c2b
# Out:
#            0.2      0.25       0.3      0.35       0.4      0.45       0.5
# 0.10  4.189052  0.975286  0.997578  1.000000  2.078774  0.899050  4.150316
# 0.15  3.175849  2.325720  0.597336  1.279783  2.220248  0.049101  0.978006
# 0.20  1.321722  1.615157  0.716011  1.047496  1.287619  2.844077  5.631070
# 0.25  0.692649  0.584668  2.497068  1.746397  0.862524  2.223775  1.979290
# 0.30  0.479074  2.395480  0.841716  1.953072  5.419443  0.507236  0.600381
# 0.35  1.612846  1.104081  0.502215  2.778562  0.726248  2.795349  0.919283
# 0.40  0.350988  1.784461  2.598694  0.808276  1.034656  0.416597  7.802921

# %%
b2c
# Out:
#            0.2      0.25       0.3      0.35       0.4      0.45       0.5
# 0.10  4.256258  1.978468  1.782588  0.500000  2.460296  1.140262  5.732035
# 0.15  2.630956  1.865063  0.835007  4.280720  2.319117  1.133893  1.897491
# 0.20  1.955936  1.723798  1.681412  1.361076  1.673683  0.960069  1.427688
# 0.25  1.707688  3.305227  1.483878  1.800852  1.129324  1.118291  1.608962
# 0.30  1.935922  1.252154  2.590361  1.408546  4.171894  1.466752  1.997170
# 0.35  1.250662  1.328574  0.355732  1.711066  4.717839  2.488766  0.661855
# 0.40  2.281234  4.762860  0.977078  2.352103  0.865575  4.160477  2.264847

# %%
c2b.plot(colormap='coolwarm',figsize=(8,6))
plt.xlabel('Coffee Probability')
plt.ylabel('Cash to Bar Switching Ratio')
plt.legend(title='Mobile Probability')
plt.show()

# %%
b2c.plot(colormap='coolwarm',figsize=(8,6))
plt.xlabel('Coffee Probability')
plt.ylabel('Bar to Cash Switching Ratio')
plt.legend(title='Mobile Probability')
plt.show()
